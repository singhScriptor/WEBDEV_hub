// %%
const profile=["Yash","Raj","www.google.com"];
const [firstName,lastName,Website]=profile
console.log(firstName,lastName,Website)
// Out:
// Yash Raj www.google.com

// %%
const [firstName, ...otherInfo]=["Yash","Raj","www.google.com"];
console.log(firstName,otherInfo)
// Out:
// Yash [ "Raj", "www.google.com" ]

// %%
const [, , website]=["Yash","Raj","www.google.com"]
console.log(website)
// Out:
// www.google.com

// %%
const [firstName="Tony",website="sharpener"]=["Rishab"]
console.log(firstName,website)
// Out:
// Rishab sharpener

// %%
const profile={
    firstName:"Julian",
    lastName:"Anthony",
    website:"Sharpener"
}
const {firstName:forename,lastName:surname,website:onlineSite}=profile;
console.log(forename,surname,onlineSite)
// Out:
// Julian Anthony Sharpener

// %%
const profile={
    lastName:{familyName:"Smith"}
}

const {lastName:{familyName:surname}}=profile;

console.log(surname)
// Out:
// Smith

// %%
const tajMahal = {
    name: 'Taj Mahal',
    location: 'Agra',
    built: 1648,
    architecturalStyle: 'Mughal',
    dimensions: {
        area: '17 acres',
    },
    UNESCOWorldHeritage: true,
};
let {name,location, dimensions}=tajMahal
console.log(name,location,dimensions)
let {built:yearBuilt}=tajMahal
console.log(yearBuilt)

let {dimensions:{area:totalArea}}=tajMahal
console.log(totalArea)
// Out:
// Taj Mahal Agra { area: "17 acres" }
// 1648
// 17 acres
